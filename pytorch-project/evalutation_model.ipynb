# %%
import numpy as np
import pandas as pd
import torch
from sklearn.preprocessing import MinMaxScaler

# Load the CSV file containing the keypoints data
keypoints_df = pd.read_csv('./output/output_keypoints.csv')  # Update with the path to your CSV file

# Exclude non-numeric columns and preprocess the data if necessary (e.g., scaling)
numeric_columns = [col for col in keypoints_df.columns if col not in ['pose_id', 'pose']]
scaler = MinMaxScaler()
keypoints_df[numeric_columns] = scaler.fit_transform(keypoints_df[numeric_columns])

# Convert the preprocessed data into a tensor
keypoints_tensor = torch.tensor(keypoints_df[numeric_columns].values, dtype=torch.float32)

# Load the pre-trained model
model_state_dict = torch.load('./models/model.pt', map_location=torch.device('cpu'))  # Update with the path to your pre-trained model file
model = NeuralNet(input_size=101, hidden_size=200, num_classes=2)
model.load_state_dict(model_state_dict)
model.eval()

# Make predictions using the pre-trained model
with torch.no_grad():
    outputs = model(keypoints_tensor)
    _, predictions = torch.max(outputs, 1)

# Print or further process the predictions
print(predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_38263/702825581.py in ?()
#       8
#       9 # Exclude non-numeric columns and preprocess the data if necessary (e.g., scaling)
#      10 numeric_columns = [col for col in keypoints_df.columns if col not in ['pose_id', 'pose']]
#      11 scaler = MinMaxScaler()
# ---> 12 keypoints_df[numeric_columns] = scaler.fit_transform(keypoints_df[numeric_columns])
#      13
#      14 # Convert the preprocessed data into a tensor
#      15 keypoints_tensor = torch.tensor(keypoints_df[numeric_columns].values, dtype=torch.float32)
#
# ~/work/graduation/automatic_evaluation_of_physical_therapy_exercises_based_on_deep_learning/.venv/lib/python3.11/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# ...
